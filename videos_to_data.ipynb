# %%
from utils import detect
import os

# %%
path = r"D:\Documents\Philips\Artifact\Data\fluo_sid\videos\josef_isreals"

# %%
for video in os.listdir(path):
    #if ".avi" in video:
    video_path = os.path.join(path, video)
    print(video_path)
    detect.convert_video(video_path)
# Out:
# D:\Documents\Philips\Artifact\Data\fluo_sid\videos\dick_bruna\FocusedAreaVideo_FluoSID_Lateral_26 [2021-12-15 17_26_26_009]-[2021-12-15 17_26_26_009].avi
# D:\Documents\Philips\Artifact\Data\fluo_sid\videos\FocusedAreaVideo_FluoSID_Lateral_26 [2021-12-15 17_26_26_009]-[2021-12-15 17_26_26_009]
# Done with video...
# D:\Documents\Philips\Artifact\Data\fluo_sid\videos\dick_bruna\FocusedAreaVideo_FluoSID_Lateral_30 [2021-12-15 17_40_16_018]-[2021-12-15 17_40_16_018].avi
# D:\Documents\Philips\Artifact\Data\fluo_sid\videos\FocusedAreaVideo_FluoSID_Lateral_30 [2021-12-15 17_40_16_018]-[2021-12-15 17_40_16_018]
# Done with video...
# D:\Documents\Philips\Artifact\Data\fluo_sid\videos\dick_bruna\FocusedAreaVideo_FluoSID_Lateral_30 [2021-12-15 17_40_56_879]-[2021-12-15 17_40_56_879].avi
# D:\Documents\Philips\Artifact\Data\fluo_sid\videos\FocusedAreaVideo_FluoSID_Lateral_30 [2021-12-15 17_40_56_879]-[2021-12-15 17_40_56_879]
# Done with video...
# ...
